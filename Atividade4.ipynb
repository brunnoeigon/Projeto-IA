# %% [markdown]
# <a href="https://colab.research.google.com/github/brunnoeigon/Projeto-IA/blob/main/Atividade4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n1, n2 = 0, 0 # Atribuído valores inteiros para n1 e n2
print ("ola mundo")

print (5+5-2)
print (n1)
print (5**2)
print (n2)
# Out:
# ola mundo
# 8
# 0
# 25
# 0
