# %% [markdown]
# <a href="https://colab.research.google.com/github/brunnoeigon/Projeto-IA/blob/main/Atividade3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("ola mundo")
# Out:
# ola mundo

# %%
2 + 3
# Out:
# 5

# %%
50-5*7
# Out:
# 15

# %%
print(int(8/5)) #divisao com operadores inteiros, retorna resultado inteiro (vs.2.7)
print(8./5) #divisao com pelo menos um operando real, retorna resultado real (vs.2.7)
# Out:
# 1
# 1.6

# %%
5**2 #elevado ao quadrado
# Out:
# 25

# %%
59**-2
# Out:
# 0.0002872737719046251

# %%
numero = 59
resultado = bin(numero)
print(resultado) #saida '0b111b11"
# Out:
# 0b111011

# %%
print(int(10 + 10))
print (int(120 - 20))
print(int(9 * 3))
print(int(25/5))
# Out:
# 20
# 100
# 27
# 5
