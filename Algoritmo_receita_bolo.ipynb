# %% [markdown]
# <a href="https://colab.research.google.com/github/brunnoeigon/Projeto-IA/blob/main/Algoritmo_receita_bolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time # Biblioteca pra simular o tempo passando

# %%
print("---INICIANDO O ALGORITMO DO BOLO---")
# Out:
# ---INICIANDO O ALGORITMO DO BOLO---

# %%
#1. Variaveis: SEPARANDO OS IGREDIENTES E FERRAMENTAS
temperatura_forno = 0
forma_untada = True
tigela = [] # Uma lista vazia colocar os ingredientes
massa_homogenea = False
tempo_de_forno = 40
palito_limpo = False

# %%
#2. Entrada/Acoes Simples
